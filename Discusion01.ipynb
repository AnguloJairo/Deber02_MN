# %% [markdown]
# # Discusión 1
# ![image.png](attachment:image.png)

# %%
def suma_orden_inverso(x):
    suma = 0
    for i in range(len(x) - 1, -1, -1):  # desde el último índice hasta el 0
        suma += x[i]
    return suma

x = [1, 2, 3, 4, 5]
resultado = suma_orden_inverso(x)
print("Suma en orden inverso:", resultado)
# Out:
# Suma en orden inverso: 15
